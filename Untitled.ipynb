# %% [markdown]
# ## Data Visualization Project

# %%
import pandas as pd
import seaborn as sns
import csv
import matplotlib as plt

# %%
df = pd.read_csv('201908-baywheels-tripdata.csv')

# %%
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         68145  2019-08-31 21:27:42.2530  2019-09-01 16:23:27.4920
# 1         53216  2019-08-31 22:34:17.5120  2019-09-01 13:21:13.9310
# 2         53182  2019-08-31 22:34:49.9420  2019-09-01 13:21:12.4570
# 3         75682  2019-08-31 14:22:02.2780  2019-09-01 11:23:24.5110
# 4         30849  2019-08-31 18:47:08.0570  2019-09-01 03:21:17.6970
#
#    start_station_id         start_station_name  start_station_latitude  \
# 0               249  Russell St at College Ave               37.858473
# 1               368       Myrtle St at Polk St               37.785434
# 2               368       Myrtle St at Polk St               37.785434
# 3               104          4th St at 16th St               37.767045
# 4               327  5th St at San Salvador St               37.332039
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0              -122.253253             247  Fulton St at Bancroft Way
# 1              -122.419622              78        Folsom St at 9th St
# 2              -122.419622              78        Folsom St at 9th St
# 3              -122.390833             126                Esprit Park
# 4              -121.881766             327  5th St at San Salvador St
#
#    end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0             37.867789            -122.265896     3112    Customer
# 1             37.773717            -122.411647     2440    Customer
# 2             37.773717            -122.411647     9743    Customer
# 3             37.761634            -122.390648    11418  Subscriber
# 4             37.332039            -121.881766     1553    Customer
#
#    member_birth_year member_gender bike_share_for_all_trip
# 0                NaN           NaN                      No
# 1             1993.0        Female                      No
# 2             1995.0          Male                      No
# 3             1993.0        Female                      No
# 4                NaN           NaN                      No

# %%
df.shape
# Out:
# (210563, 16)

# %%
df.dtypes
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id             int64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id               int64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %%
#Fix the timestamp issue
df.start_time = pd.to_datetime(df.start_time)
df.end_time = pd.to_datetime(df.end_time)
df.dtypes
# Out:
# duration_sec                        int64
# start_time                 datetime64[ns]
# end_time                   datetime64[ns]
# start_station_id                    int64
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_station_id                      int64
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# bike_id                             int64
# user_type                          object
# member_birth_year                 float64
# member_gender                      object
# bike_share_for_all_trip            object
# dtype: object

# %%
df.describe()
# Out:
#        duration_sec  start_station_id  start_station_latitude  \
# count  210563.00000     210563.000000           210563.000000
# mean      833.51472        144.829481               37.770058
# std      1928.22378        120.128023                0.102810
# min        61.00000          3.000000               37.311284
# 25%       376.00000         50.000000               37.770407
# 50%       593.00000        104.000000               37.780526
# 75%       914.00000        240.000000               37.795393
# max     85492.00000        459.000000               45.510000
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            210563.000000   210563.000000         210563.000000
# mean               -122.354407      140.921145             37.770268
# std                   0.217648      118.990674              0.102675
# min                -122.473658        3.000000             37.311284
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285       99.000000             37.780787
# 75%                -122.294837      233.000000             37.797280
# max                 -73.570000      459.000000             45.510000
#
#        end_station_longitude        bike_id  member_birth_year
# count          210563.000000  210563.000000      170774.000000
# mean             -122.353604    4048.755897        1984.964450
# std                 0.217245    3639.124465          10.037432
# min              -122.473658      12.000000        1878.000000
# 25%              -122.411306    1312.000000        1980.000000
# 50%              -122.397437    2629.000000        1987.000000
# 75%              -122.294837    9241.000000        1992.000000
# max               -73.570000   11945.000000        2001.000000

# %%
df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         68145 2019-08-31 21:27:42.253 2019-09-01 16:23:27.492
# 1         53216 2019-08-31 22:34:17.512 2019-09-01 13:21:13.931
# 2         53182 2019-08-31 22:34:49.942 2019-09-01 13:21:12.457
# 3         75682 2019-08-31 14:22:02.278 2019-09-01 11:23:24.511
# 4         30849 2019-08-31 18:47:08.057 2019-09-01 03:21:17.697
#
#    start_station_id         start_station_name  start_station_latitude  \
# 0               249  Russell St at College Ave               37.858473
# 1               368       Myrtle St at Polk St               37.785434
# 2               368       Myrtle St at Polk St               37.785434
# 3               104          4th St at 16th St               37.767045
# 4               327  5th St at San Salvador St               37.332039
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0              -122.253253             247  Fulton St at Bancroft Way
# 1              -122.419622              78        Folsom St at 9th St
# 2              -122.419622              78        Folsom St at 9th St
# 3              -122.390833             126                Esprit Park
# 4              -121.881766             327  5th St at San Salvador St
#
#    end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0             37.867789            -122.265896     3112    Customer
# 1             37.773717            -122.411647     2440    Customer
# 2             37.773717            -122.411647     9743    Customer
# 3             37.761634            -122.390648    11418  Subscriber
# 4             37.332039            -121.881766     1553    Customer
#
#    member_birth_year member_gender bike_share_for_all_trip
# 0                NaN           NaN                      No
# 1             1993.0        Female                      No
# 2             1995.0          Male                      No
# 3             1993.0        Female                      No
# 4                NaN           NaN                      No

# %%
samp = df.sample(100000)

# %%
#creating a matrix to give us some ideas of what we could potentially plot.
pd.plotting.scatter_matrix(samp, figsize=(16,16));
#df.iloc[:, 0:2]

# %%
pd.plotting.scatter_matrix(samp, alpha=0.2, figsize=(16, 16), diagonal='kde');
#plt.show()

# %%
age = df[['member_birth_year','duration_sec']]
age = age.dropna()
age.describe()
# Out:
#        member_birth_year   duration_sec
# count      170774.000000  170774.000000
# mean         1984.964450     709.594932
# std            10.037432    1366.112039
# min          1878.000000      61.000000
# 25%          1980.000000     355.000000
# 50%          1987.000000     555.000000
# 75%          1992.000000     839.000000
# max          2001.000000   80893.000000

# %%
age.plot(kind='scatter', x='member_birth_year', y='duration_sec')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df.plot(kind='scatter', x='member_birth_year', y='bike_id')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### <p>Observations within the scatter matrix:</p>
# <ol>
# <li>Member birth year is skewed right suggesting users are millennials and the younger generation.</li>
# </ol>
# <ul>
# <li>Which age group is most prominent?</li>
# <li>What start stations are they using?</li>
# <li>What end stations are they using?</li>
# <li>Who uses the bike sharing more men vs women?</li>
# </ul>

# %% [markdown]
# ### Lets create user groups based on generation.
# <p>
# <li><em>Baby Boomers</em> between years 1946 – 1964</li>
#     <li><em>Generation X</em> between years 1965 – 1980</li>
#     <li><em>Millennials</em> between years 1981 – 1996</li>

# %%
#Query Boomers
boomers = df[(df['member_birth_year'] >= 1946) & (df['member_birth_year'] <= 1964)]
#Query Genx
genx = df[(df['member_birth_year'] >= 1965) & (df['member_birth_year'] <= 1980)]
#Query Milennials
mil = df[(df['member_birth_year'] >= 1981) & (df['member_birth_year'] <= 1996)]

# %%
genx.head()
# Out:
#     duration_sec              start_time                end_time  \
# 6           8959 2019-08-31 22:44:38.213 2019-09-01 01:13:57.248
# 10          1624 2019-08-31 23:55:17.390 2019-09-01 00:22:22.132
# 11          1419 2019-08-31 23:58:09.400 2019-09-01 00:21:48.622
# 27           265 2019-08-31 23:53:42.193 2019-08-31 23:58:07.850
# 32          2627 2019-08-31 23:10:41.653 2019-08-31 23:54:29.429
#
#     start_station_id                            start_station_name  \
# 6                323                            Broadway at Kearny
# 10               276                      Julian St at The Alameda
# 11               259                       Addison St at Fourth St
# 27                 3  Powell St BART Station (Market St at 4th St)
# 32               312                      San Jose Diridon Station
#
#     start_station_latitude  start_station_longitude  end_station_id  \
# 6                37.798014              -122.405950               8
# 10               37.332233              -121.912517             276
# 11               37.866249              -122.299371             268
# 27               37.786375              -122.404904              36
# 32               37.329732              -121.901782             276
#
#                  end_station_name  end_station_latitude  \
# 6   The Embarcadero at Vallejo St             37.799953
# 10       Julian St at The Alameda             37.332233
# 11     Ellsworth St at Russell St             37.857490
# 27            Folsom St at 3rd St             37.783830
# 32       Julian St at The Alameda             37.332233
#
#     end_station_longitude  bike_id   user_type  member_birth_year  \
# 6             -122.398525     3028    Customer             1970.0
# 10            -121.912517    10567  Subscriber             1969.0
# 11            -122.261578     3590  Subscriber             1976.0
# 27            -122.398870     9960  Subscriber             1973.0
# 32            -121.912517    10567  Subscriber             1969.0
#
#    member_gender bike_share_for_all_trip
# 6         Female                      No
# 10          Male                     Yes
# 11        Female                      No
# 27          Male                      No
# 32          Male                     Yes

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="name", y="count", data=table, label="Total", color="#006622")

plt.xlabel('Dog Names')
plt.ylabel('Name Occurrence')
plt.title("Most Common Dog Names")
plt.savefig('popular_dog_names')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-171-4f3916aed4cd> in <module>
#       9 # Plot the total crashes
#      10 sns.set_color_codes("pastel")
# ---> 11 sns.barplot(x="name", y="count", data=table, label="Total", color="#006622")
#      12
#      13 plt.xlabel('Dog Names')
#
# NameError: name 'table' is not defined
