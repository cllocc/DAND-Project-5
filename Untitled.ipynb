# %% [markdown]
# ## Exploratory Data Visualization

# %%
import sqlite3
import pandas.io.sql as sql
import pandas as pd
import seaborn as sns
import geopandas as gdp
from shapely.geometry import Point,Polygon
import csv
import matplotlib.pyplot as plt
import gmaps

# %% [markdown]
# ### Using SQL for Advanced Querying

# %%
#A script to create and import a .csv into sqlite3
'''con = sqlite3.connect("bikeshare.db")
cur = con.cursor()
cur.execute("CREATE TABLE bike_share (id INTEGER PRIMARY KEY,duration_sec int64(50),"
            "start_time datetime,end_time datetime,start_station_id int64,start_station_name varchar(255),start_station_latitude float(1,10),start_station_longitude float(1,10),end_station_id int64(50),end_station_name varchar(255),end_station_latitude float(1,10),end_station_longitude float(1,10),bike_id int64,user_type varchar(255),member_birth_year int,member_gender varchar(255),bike_share_for_all_trip varchar(255) );")

with open('201908-baywheels-tripdata.csv','r', encoding='utf-8') as fin: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['duration_sec'],i['start_time'],i['end_time'],i['start_station_id'],i['start_station_name'],i['start_station_latitude'],i['start_station_longitude'],i['end_station_id'],i['end_station_name'],i['end_station_latitude'],i['end_station_longitude'],i['bike_id'],i['user_type'],i['member_birth_year'],i['member_gender'],i['bike_share_for_all_trip']) for i in dr]

cur.executemany("INSERT INTO bike_share (duration_sec,start_time,end_time,start_station_id,start_station_name,start_station_latitude,start_station_longitude,end_station_id,end_station_name,end_station_latitude,end_station_longitude,bike_id,user_type,member_birth_year,member_gender,bike_share_for_all_trip) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?);", to_db)
con.commit()'''
# Out:
# 'con = sqlite3.connect("bikeshare.db")\ncur = con.cursor()\ncur.execute("CREATE TABLE bike_share (id INTEGER PRIMARY KEY,duration_sec int64(50),"\n            "start_time datetime,end_time datetime,start_station_id int64,start_station_name varchar(255),start_station_latitude float(1,10),start_station_longitude float(1,10),end_station_id int64(50),end_station_name varchar(255),end_station_latitude float(1,10),end_station_longitude float(1,10),bike_id int64,user_type varchar(255),member_birth_year int,member_gender varchar(255),bike_share_for_all_trip varchar(255) );")\n\nwith open(\'201908-baywheels-tripdata.csv\',\'r\', encoding=\'utf-8\') as fin: # `with` statement available in 2.5+\n    # csv.DictReader uses first line in file for column headings by default\n    dr = csv.DictReader(fin) # comma is default delimiter\n    to_db = [(i[\'duration_sec\'],i[\'start_time\'],i[\'end_time\'],i[\'start_station_id\'],i[\'start_station_name\'],i[\'start_station_latitude\'],i[\'start_station_longitude\'],i[\'end_station_id\'],i[\'end_station_name\'],i[\'end_station_latitude\'],i[\'end_station_longitude\'],i[\'bike_id\'],i[\'user_type\'],i[\'member_birth_year\'],i[\'member_gender\'],i[\'bike_share_for_all_trip\']) for i in dr]\n\ncur.executemany("INSERT INTO bike_share (duration_sec,start_time,end_time,start_station_id,start_station_name,start_station_latitude,start_station_longitude,end_station_id,end_station_name,end_station_latitude,end_station_longitude,bike_id,user_type,member_birth_year,member_gender,bike_share_for_all_trip) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?);", to_db)\ncon.commit()'

# %% [markdown]
# #### Let’s check our data all of our data and then run another query to see if we have any duplicated user ID’s

# %%
#Query all of our data
con = sqlite3.connect("bikeshare.db")
df = sql.read_sql('SELECT * from bike_share', con)
df
# Out:
#             id  duration_sec                start_time  \
# 0            1         68145  2019-08-31 21:27:42.2530
# 1            2         53216  2019-08-31 22:34:17.5120
# 2            3         53182  2019-08-31 22:34:49.9420
# 3            4         75682  2019-08-31 14:22:02.2780
# 4            5         30849  2019-08-31 18:47:08.0570
# ...        ...           ...                       ...
# 210558  210559           728  2019-08-01 00:07:37.0390
# 210559  210560           761  2019-08-01 00:06:23.8300
# 210560  210561           331  2019-08-01 00:08:28.7570
# 210561  210562           111  2019-08-01 00:11:02.5820
# 210562  210563           255  2019-08-01 00:04:27.9530
#
#                         end_time  start_station_id  \
# 0       2019-09-01 16:23:27.4920               249
# 1       2019-09-01 13:21:13.9310               368
# 2       2019-09-01 13:21:12.4570               368
# 3       2019-09-01 11:23:24.5110               104
# 4       2019-09-01 03:21:17.6970               327
# ...                          ...               ...
# 210558  2019-08-01 00:19:45.7760                67
# 210559  2019-08-01 00:19:05.5500               151
# 210560  2019-08-01 00:14:00.1350                30
# 210561  2019-08-01 00:12:54.1340               183
# 210562  2019-08-01 00:08:43.3370               104
#
#                                        start_station_name  \
# 0                               Russell St at College Ave
# 1                                    Myrtle St at Polk St
# 2                                    Myrtle St at Polk St
# 3                                       4th St at 16th St
# 4                               5th St at San Salvador St
# ...                                                   ...
# 210558  San Francisco Caltrain Station 2  (Townsend St...
# 210559                               53rd St at Hollis St
# 210560     San Francisco Caltrain (Townsend St at 4th St)
# 210561                           Telegraph Ave at 19th St
# 210562                                  4th St at 16th St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.858473              -122.253253             247
# 1                    37.785434              -122.419622              78
# 2                    37.785434              -122.419622              78
# 3                    37.767045              -122.390833             126
# 4                    37.332039              -121.881766             327
# ...                        ...                      ...             ...
# 210558               37.776639              -122.395526              17
# 210559               37.836182              -122.287180             159
# 210560               37.776598              -122.395282              62
# 210561               37.808702              -122.269927             180
# 210562               37.767045              -122.390833             104
#
#                                         end_station_name  \
# 0                              Fulton St at Bancroft Way
# 1                                    Folsom St at 9th St
# 2                                    Folsom St at 9th St
# 3                                            Esprit Park
# 4                              5th St at San Salvador St
# ...                                                  ...
# 210558  Embarcadero BART Station (Beale St at Market St)
# 210559                              24th St at Market St
# 210560                       Victoria Manalo Draves Park
# 210561                          Telegraph Ave at 23rd St
# 210562                                 4th St at 16th St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0                  37.867789            -122.265896     3112    Customer
# 1                  37.773717            -122.411647     2440    Customer
# 2                  37.773717            -122.411647     9743    Customer
# 3                  37.761634            -122.390648    11418  Subscriber
# 4                  37.332039            -121.881766     1553    Customer
# ...                      ...                    ...      ...         ...
# 210558             37.792251            -122.397086     2500  Subscriber
# 210559             37.816060            -122.278244      613  Subscriber
# 210560             37.777791            -122.406432     2904  Subscriber
# 210561             37.812678            -122.268773     1910  Subscriber
# 210562             37.767045            -122.390833     3703  Subscriber
#
#        member_birth_year member_gender bike_share_for_all_trip
# 0                                                           No
# 1                   1993        Female                      No
# 2                   1995          Male                      No
# 3                   1993        Female                      No
# 4                                                           No
# ...                  ...           ...                     ...
# 210558              1983          Male                      No
# 210559              1982        Female                      No
# 210560              1994          Male                      No
# 210561              1993          Male                      No
# 210562              1990          Male                      No
#
# [210563 rows x 17 columns]

# %%
#Check distinct ID
con = sqlite3.connect("bikeshare.db")
dupes = sql.read_sql('SELECT DISTINCT id from bike_share ', con)
dupes
# Out:
#             id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 210558  210559
# 210559  210560
# 210560  210561
# 210561  210562
# 210562  210563
#
# [210563 rows x 1 columns]

# %% [markdown]
# After doing a check we know there are no duplicated records both match (210563) rows

# %%
#Checking our data types
df.dtypes
# Out:
# id                           int64
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id             int64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id               int64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year           object
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %%
#Check the shape of the data
df.shape
# Out:
# (210563, 17)

# %%
#Fix the timestamp issue when converting to pandas.
df.start_time = pd.to_datetime(df.start_time)
df.end_time = pd.to_datetime(df.end_time)
df.dtypes
# Out:
# id                                  int64
# duration_sec                        int64
# start_time                 datetime64[ns]
# end_time                   datetime64[ns]
# start_station_id                    int64
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_station_id                      int64
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# bike_id                             int64
# user_type                          object
# member_birth_year                  object
# member_gender                      object
# bike_share_for_all_trip            object
# dtype: object

# %% [markdown]
# Run a query where birth_year is not null.

# %%
#Query the data where birth_year not null
birth = sql.read_sql('SELECT * from bike_share where member_birth_year != "" ', con)
birth
# Out:
#             id  duration_sec                start_time  \
# 0            2         53216  2019-08-31 22:34:17.5120
# 1            3         53182  2019-08-31 22:34:49.9420
# 2            4         75682  2019-08-31 14:22:02.2780
# 3            7          8959  2019-08-31 22:44:38.2130
# 4           11          1624  2019-08-31 23:55:17.3900
# ...        ...           ...                       ...
# 170769  210559           728  2019-08-01 00:07:37.0390
# 170770  210560           761  2019-08-01 00:06:23.8300
# 170771  210561           331  2019-08-01 00:08:28.7570
# 170772  210562           111  2019-08-01 00:11:02.5820
# 170773  210563           255  2019-08-01 00:04:27.9530
#
#                         end_time  start_station_id  \
# 0       2019-09-01 13:21:13.9310               368
# 1       2019-09-01 13:21:12.4570               368
# 2       2019-09-01 11:23:24.5110               104
# 3       2019-09-01 01:13:57.2480               323
# 4       2019-09-01 00:22:22.1320               276
# ...                          ...               ...
# 170769  2019-08-01 00:19:45.7760                67
# 170770  2019-08-01 00:19:05.5500               151
# 170771  2019-08-01 00:14:00.1350                30
# 170772  2019-08-01 00:12:54.1340               183
# 170773  2019-08-01 00:08:43.3370               104
#
#                                        start_station_name  \
# 0                                    Myrtle St at Polk St
# 1                                    Myrtle St at Polk St
# 2                                       4th St at 16th St
# 3                                      Broadway at Kearny
# 4                                Julian St at The Alameda
# ...                                                   ...
# 170769  San Francisco Caltrain Station 2  (Townsend St...
# 170770                               53rd St at Hollis St
# 170771     San Francisco Caltrain (Townsend St at 4th St)
# 170772                           Telegraph Ave at 19th St
# 170773                                  4th St at 16th St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.785434              -122.419622              78
# 1                    37.785434              -122.419622              78
# 2                    37.767045              -122.390833             126
# 3                    37.798014              -122.405950               8
# 4                    37.332233              -121.912516             276
# ...                        ...                      ...             ...
# 170769               37.776639              -122.395526              17
# 170770               37.836182              -122.287180             159
# 170771               37.776598              -122.395282              62
# 170772               37.808702              -122.269927             180
# 170773               37.767045              -122.390833             104
#
#                                         end_station_name  \
# 0                                    Folsom St at 9th St
# 1                                    Folsom St at 9th St
# 2                                            Esprit Park
# 3                          The Embarcadero at Vallejo St
# 4                               Julian St at The Alameda
# ...                                                  ...
# 170769  Embarcadero BART Station (Beale St at Market St)
# 170770                              24th St at Market St
# 170771                       Victoria Manalo Draves Park
# 170772                          Telegraph Ave at 23rd St
# 170773                                 4th St at 16th St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0                  37.773717            -122.411647     2440    Customer
# 1                  37.773717            -122.411647     9743    Customer
# 2                  37.761634            -122.390648    11418  Subscriber
# 3                  37.799953            -122.398525     3028    Customer
# 4                  37.332233            -121.912516    10567  Subscriber
# ...                      ...                    ...      ...         ...
# 170769             37.792251            -122.397086     2500  Subscriber
# 170770             37.816060            -122.278244      613  Subscriber
# 170771             37.777791            -122.406432     2904  Subscriber
# 170772             37.812678            -122.268773     1910  Subscriber
# 170773             37.767045            -122.390833     3703  Subscriber
#
#         member_birth_year member_gender bike_share_for_all_trip
# 0                    1993        Female                      No
# 1                    1995          Male                      No
# 2                    1993        Female                      No
# 3                    1970        Female                      No
# 4                    1969          Male                     Yes
# ...                   ...           ...                     ...
# 170769               1983          Male                      No
# 170770               1982        Female                      No
# 170771               1994          Male                      No
# 170772               1993          Male                      No
# 170773               1990          Male                      No
#
# [170774 rows x 17 columns]

# %% [markdown]
# Let’s see what genders are using the bike share program most.

# %%
#Query our data and store it into a pandas dataframe
gender = sql.read_sql('SELECT member_gender, COUNT(member_gender) as count FROM bike_share WHERE member_gender !="" GROUP BY member_gender ORDER BY COUNT(member_gender) DESC', con)
gender
# Out:
#   member_gender   count
# 0          Male  128285
# 1        Female   40054
# 2         Other    2438

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="member_gender", y="count", data=gender,label="Total", color="#79B8D5")

plt.xlabel('')
plt.ylabel('')
plt.title("Bike Share Genders")
# Out:
# Text(0.5, 1.0, 'Bike Share Genders')

# %%
#Query our data and store it into a pandas dataframe
user = sql.read_sql('SELECT user_type, COUNT(user_type) as count FROM bike_share WHERE user_type !="" GROUP BY user_type ORDER BY COUNT(user_type) DESC', con)
user
# Out:
#     user_type   count
# 0  Subscriber  164928
# 1    Customer   45635

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="user_type", y="count", data=user,label="Total", color="#D4DF8C")

plt.xlabel('')
plt.ylabel('')
plt.title("Bike Share Subcribers vs Non Subscribers")
# Out:
# Text(0.5, 1.0, 'Bike Share Subcribers vs Non Subscribers')

# %%
#Query our data and store it into a pandas dataframe
pop_bike = sql.read_sql('SELECT bike_id, COUNT(bike_id) as count FROM bike_share WHERE bike_id !="" GROUP BY bike_id ORDER BY COUNT(bike_id) DESC', con)
pop_bike20 = pop_bike.head(20)
pop_bike20
# Out:
#     bike_id  count
# 0      9477    175
# 1      3028    166
# 2      9467    166
# 3      1124    162
# 4      3589    159
# 5      1624    156
# 6       954    153
# 7      9555    152
# 8      3089    150
# 9      3386    149
# 10     3744    149
# 11     2293    148
# 12     2526    148
# 13     1204    147
# 14     2174    147
# 15     3491    147
# 16     1554    146
# 17     2771    146
# 18     2994    146
# 19     3135    146

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="bike_id", y="count", data=pop_bike20,label="Total", color="#A4DF8C")

plt.xlabel('')
plt.ylabel('Count')
plt.title('Most Frequently Used Bikes')
#plt.savefig('name_here')
# Out:
# Text(0.5, 1.0, 'Most Frequently Used Bikes')

# %%
df.head()
# Out:
#    id  duration_sec              start_time                end_time  \
# 0   1         68145 2019-08-31 21:27:42.253 2019-09-01 16:23:27.492
# 1   2         53216 2019-08-31 22:34:17.512 2019-09-01 13:21:13.931
# 2   3         53182 2019-08-31 22:34:49.942 2019-09-01 13:21:12.457
# 3   4         75682 2019-08-31 14:22:02.278 2019-09-01 11:23:24.511
# 4   5         30849 2019-08-31 18:47:08.057 2019-09-01 03:21:17.697
#
#    start_station_id         start_station_name  start_station_latitude  \
# 0               249  Russell St at College Ave               37.858473
# 1               368       Myrtle St at Polk St               37.785434
# 2               368       Myrtle St at Polk St               37.785434
# 3               104          4th St at 16th St               37.767045
# 4               327  5th St at San Salvador St               37.332039
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0              -122.253253             247  Fulton St at Bancroft Way
# 1              -122.419622              78        Folsom St at 9th St
# 2              -122.419622              78        Folsom St at 9th St
# 3              -122.390833             126                Esprit Park
# 4              -121.881766             327  5th St at San Salvador St
#
#    end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0             37.867789            -122.265896     3112    Customer
# 1             37.773717            -122.411647     2440    Customer
# 2             37.773717            -122.411647     9743    Customer
# 3             37.761634            -122.390648    11418  Subscriber
# 4             37.332039            -121.881766     1553    Customer
#
#   member_birth_year member_gender bike_share_for_all_trip
# 0                                                      No
# 1              1993        Female                      No
# 2              1995          Male                      No
# 3              1993        Female                      No
# 4                                                      No

# %% [markdown]
# Let’s make some histograms and scatter plots for areas of interest.

# %%
#Age group using the bike share program
birth.hist(column='member_birth_year');

# %%
#Age group using the bike share program
birth.plot(kind='scatter', x='member_birth_year', y='duration_sec');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Which bikes are being used the most?
df.hist(column='bike_id');

# %%
#How long are bikes being used?
df.plot(kind='scatter', x='bike_id', y='duration_sec');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#What beginning stations are popular?
df.hist(column='start_station_id');

# %%
#Start station vs member birth year
birth.plot(kind='scatter', x='start_station_id', y='member_birth_year');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df.hist(column='end_station_id');

# %%
#Start station vs member birth year
birth.plot(kind='scatter', x='end_station_id', y='member_birth_year');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Query our data and store it into a pandas dataframe
station = sql.read_sql('SELECT start_station_name, COUNT(start_station_name) as count FROM bike_share WHERE start_station_name !="" GROUP BY start_station_name ORDER BY COUNT(start_station_name) DESC', con)
pop_station = station.head(5)
unpop_station = station.tail(5)

# %%
#popular stations
pop_station
# Out:
#                                   start_station_name  count
# 0  San Francisco Caltrain Station 2  (Townsend St...   5196
# 1                                 Berry St at 4th St   4156
# 2  San Francisco Ferry Building (Harry Bridges Pl...   3714
# 3                               Market St at 10th St   3543
# 4   Montgomery St BART Station (Market St at 2nd St)   3092

# %%
#unpopular stations
unpop_station
# Out:
#                  start_station_name  count
# 372              Utah St at 24th St     11
# 373           1st St at Younger Ave      8
# 374  21st Ave at International Blvd      7
# 375                     MTL-ECO5-01      3
# 376                   16th St Depot      2

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="start_station_name", y="count", data=pop_station, label="Total", color="#5F9C46")

plt.xlabel('')
plt.ylabel('')
plt.title("Most Popular Starting Stations")
plt.savefig('popular_dog_names')
plt.xticks(rotation=-70);

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="start_station_name", y="count", data=unpop_station, label="Total", color="#E7604D")

plt.xlabel('')
plt.ylabel('')
plt.title("Least Popular Starting Stations")
plt.xticks(rotation=-70);

# %%
df.head()
# Out:
#    id  duration_sec              start_time                end_time  \
# 0   1         68145 2019-08-31 21:27:42.253 2019-09-01 16:23:27.492
# 1   2         53216 2019-08-31 22:34:17.512 2019-09-01 13:21:13.931
# 2   3         53182 2019-08-31 22:34:49.942 2019-09-01 13:21:12.457
# 3   4         75682 2019-08-31 14:22:02.278 2019-09-01 11:23:24.511
# 4   5         30849 2019-08-31 18:47:08.057 2019-09-01 03:21:17.697
#
#    start_station_id         start_station_name  start_station_latitude  \
# 0               249  Russell St at College Ave               37.858473
# 1               368       Myrtle St at Polk St               37.785434
# 2               368       Myrtle St at Polk St               37.785434
# 3               104          4th St at 16th St               37.767045
# 4               327  5th St at San Salvador St               37.332039
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0              -122.253253             247  Fulton St at Bancroft Way
# 1              -122.419622              78        Folsom St at 9th St
# 2              -122.419622              78        Folsom St at 9th St
# 3              -122.390833             126                Esprit Park
# 4              -121.881766             327  5th St at San Salvador St
#
#    end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0             37.867789            -122.265896     3112    Customer
# 1             37.773717            -122.411647     2440    Customer
# 2             37.773717            -122.411647     9743    Customer
# 3             37.761634            -122.390648    11418  Subscriber
# 4             37.332039            -121.881766     1553    Customer
#
#   member_birth_year member_gender bike_share_for_all_trip
# 0                                                      No
# 1              1993        Female                      No
# 2              1995          Male                      No
# 3              1993        Female                      No
# 4                                                      No

# %%
df.boxplot(by ='bike_share_for_all_trip', column =['bike_id'], grid = False) ;

# %%
#Let's Check what other variables we can work with.
df.describe()
# Out:
#                   id  duration_sec  start_station_id  start_station_latitude  \
# count  210563.000000  210563.00000     210563.000000           210563.000000
# mean   105282.000000     833.51472        144.829481               37.770058
# std     60784.446703    1928.22378        120.128023                0.102810
# min         1.000000      61.00000          3.000000               37.311284
# 25%     52641.500000     376.00000         50.000000               37.770407
# 50%    105282.000000     593.00000        104.000000               37.780526
# 75%    157922.500000     914.00000        240.000000               37.795393
# max    210563.000000   85492.00000        459.000000               45.510000
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            210563.000000   210563.000000         210563.000000
# mean               -122.354407      140.921145             37.770268
# std                   0.217648      118.990674              0.102675
# min                -122.473658        3.000000             37.311284
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285       99.000000             37.780787
# 75%                -122.294837      233.000000             37.797280
# max                 -73.570000      459.000000             45.510000
#
#        end_station_longitude        bike_id
# count          210563.000000  210563.000000
# mean             -122.353604    4048.755897
# std                 0.217245    3639.124465
# min              -122.473658      12.000000
# 25%              -122.411306    1312.000000
# 50%              -122.397437    2629.000000
# 75%              -122.294837    9241.000000
# max               -73.570000   11945.000000

# %%
#creating a matrix to give us some ideas of what we could potentially plot.
pd.plotting.scatter_matrix(df, figsize=(16,16));
#df.iloc[:, 0:2]

# %%
pd.plotting.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde');
#plt.show()

# %% [markdown]
# ### <p>Observations within the scatter matrix:</p>
# <ol>
# <li>Member birth year is skewed right suggesting users are millennials and the younger generation are majority users of the program.</li>
# </ol>
# <ul>
# <li>Which age group is most prominent?</li>
# <li>What start stations are they using?</li>
# <li>What end stations are they using?</li>
# <li>Who uses the bike sharing more men vs women?</li>
# </ul>

# %% [markdown]
# ### Lets create user groups based on generation.
# <p>
# <li><em>Baby Boomers</em> between years 1946 – 1964</li>
#     <li><em>Generation X</em> between years 1965 – 1980</li>
#     <li><em>Millennials</em> between years 1981 – 1996</li>

# %% [markdown]
# ### Let’s take a look at where our bike share locations on a map.

# %%
#Query all of our data
con = sqlite3.connect("bikeshare.db")
locations_df = sql.read_sql('SELECT DISTINCT start_station_id, start_station_longitude, start_station_latitude from bike_share', con)
locations_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude
# 0                 249              -122.253253               37.858473
# 1                 368              -122.419622               37.785434
# 2                 104              -122.390833               37.767045
# 3                 327              -121.881766               37.332039
# 4                  49              -122.394989               37.780760
# ..                ...                      ...                     ...
# 372               391              -121.904436               37.355030
# 373               421              -121.878778               37.360001
# 374               344              -122.396292               37.766349
# 375               408               -73.570000               45.510000
# 376               367              -122.473658               37.771104
#
# [377 rows x 3 columns]

# %%
bay_area = gdp.read_file('shape/s7jc7v.shp')

# %%
fig,ax = plt.subplots(figsize = (15,15))
bay_area.plot(ax = ax)

# %%
crs = {'init': 'epsg:4326'}
geometry = [Point(xy) for xy in zip(locations_df["start_station_longitude"], locations_df["start_station_latitude"])]

locations_df = gdp.GeoDataFrame(locations_df,#Specify our data
                                crs = crs,#specify our coordinate reference system
                                geometry = geometry)#Specify the geometry list we created

locations_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude  \
# 0                 249              -122.253253               37.858473
# 1                 368              -122.419622               37.785434
# 2                 104              -122.390833               37.767045
# 3                 327              -121.881766               37.332039
# 4                  49              -122.394989               37.780760
# ..                ...                      ...                     ...
# 372               391              -121.904436               37.355030
# 373               421              -121.878778               37.360001
# 374               344              -122.396292               37.766349
# 375               408               -73.570000               45.510000
# 376               367              -122.473658               37.771104
#
#                                          geometry
# 0                 POINT (-122.2532529 37.8584732)
# 1    POINT (-122.4196216464043 37.78543382786823)
# 2    POINT (-122.3908334970474 37.76704457969368)
# 3    POINT (-121.8817663192749 37.33203868095132)
# 4                 POINT (-122.3949894 37.7807601)
# ..                                            ...
# 372   POINT (-121.9044363498688 37.3550295822529)
# 373   POINT (-121.8787783384323 37.3600013909666)
# 374  POINT (-122.3962917923927 37.76634858593739)
# 375              POINT (-73.56999999999999 45.51)
# 376                 POINT (-122.473658 37.771104)
#
# [377 rows x 4 columns]

# %%
fig,ax = plt.subplots(figsize = (15,15))
bay_area.plot(ax = ax, alpha = 0.4)

locations_df.plot(ax = ax, markersize = 20, color = "green", marker = "o", label = "",alpha=0.99)
#test.plot(ax = ax, markersize = 20, color = "blue", marker = "^", label = "Start Station Mil",alpha=0.99)
#ax.margins(x=0.25, y=-.10)   # Values in (-0.5, 0.0) zooms in to center
plt.legend(prop={'size': 15})
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# There seems to be a problem with false geo data from some of our users.
# <p>
# <li>We'll filter out coordinates that are below -120</li>

# %%
#Query all of our data
con = sqlite3.connect("bikeshare.db")
locations_df = sql.read_sql('SELECT DISTINCT start_station_id, start_station_longitude, start_station_latitude from bike_share where start_station_longitude <= -120 ', con)
locations_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude
# 0                 249              -122.253253               37.858473
# 1                 368              -122.419622               37.785434
# 2                 104              -122.390833               37.767045
# 3                 327              -121.881766               37.332039
# 4                  49              -122.394989               37.780760
# ..                ...                      ...                     ...
# 371               224              -122.239305               37.784855
# 372               391              -121.904436               37.355030
# 373               421              -121.878778               37.360001
# 374               344              -122.396292               37.766349
# 375               367              -122.473658               37.771104
#
# [376 rows x 3 columns]

# %%
#crs = {'init': 'epsg:4326'}
geometry = [Point(xy) for xy in zip(locations_df["start_station_longitude"], locations_df["start_station_latitude"])]

locations_df = gdp.GeoDataFrame(locations_df,#Specify our data
                                #crs = crs,#specify our coordinate reference system
                                geometry = geometry)#Specify the geometry list we created

locations_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude  \
# 0                 249              -122.253253               37.858473
# 1                 368              -122.419622               37.785434
# 2                 104              -122.390833               37.767045
# 3                 327              -121.881766               37.332039
# 4                  49              -122.394989               37.780760
# ..                ...                      ...                     ...
# 371               224              -122.239305               37.784855
# 372               391              -121.904436               37.355030
# 373               421              -121.878778               37.360001
# 374               344              -122.396292               37.766349
# 375               367              -122.473658               37.771104
#
#                                          geometry
# 0                 POINT (-122.2532529 37.8584732)
# 1    POINT (-122.4196216464043 37.78543382786823)
# 2    POINT (-122.3908334970474 37.76704457969368)
# 3    POINT (-121.8817663192749 37.33203868095132)
# 4                 POINT (-122.3949894 37.7807601)
# ..                                            ...
# 371  POINT (-122.2393047809601 37.78485466229441)
# 372   POINT (-121.9044363498688 37.3550295822529)
# 373   POINT (-121.8787783384323 37.3600013909666)
# 374  POINT (-122.3962917923927 37.76634858593739)
# 375                 POINT (-122.473658 37.771104)
#
# [376 rows x 4 columns]

# %%
fig,ax = plt.subplots(figsize = (15,15))
bay_area.plot(ax = ax, alpha = 0.4)

locations_df.plot(ax = ax, markersize = 20, color = "green", marker = "o", label = "Bike Share Locations",alpha=0.99)
#test.plot(ax = ax, markersize = 20, color = "blue", marker = "^", label = "Start Station Mil",alpha=0.99)
#ax.margins(x=0.25, y=-.10)   # Values in (-0.5, 0.0) zooms in to center
plt.legend(prop={'size': 15})

# %% [markdown]
# ### It looks as though we have 3 participating cities.
# <p>
# <li>Let’s zoom in a check where our stations are within their borders.</li>
#     <li>We'll start with San Francisco.</li>

# %%
#Query our data
con = sqlite3.connect("bikeshare.db")
sanfran_df = sql.read_sql('SELECT DISTINCT start_station_id, start_station_longitude, start_station_latitude from bike_share where start_station_longitude between -122.52 and -122.35 and start_station_longitude like "-122%"', con)
sanfran_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude
# 0                 368              -122.419622               37.785434
# 1                 104              -122.390833               37.767045
# 2                  49              -122.394989               37.780760
# 3                 323              -122.405950               37.798014
# 4                   5              -122.408445               37.783899
# ..                ...                      ...                     ...
# 171               361              -122.385655               37.739853
# 172               359              -122.398963               37.730168
# 173               413              -122.447723               37.720555
# 174               344              -122.396292               37.766349
# 175               367              -122.473658               37.771104
#
# [176 rows x 3 columns]

# %%
#Import our shape file
streetmap = gdp.read_file('shape/sanfran_city/geo_export_b896081a-685e-4878-a962-38b650695c1a.shp')

# %%
#Plot our shape file
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax)

# %%
#Read in the training data-set
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(sanfran_df["start_station_longitude"], sanfran_df["start_station_latitude"])]
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x2116ccfd0c8>,
#  <shapely.geometry.point.Point at 0x21171187308>,
#  <shapely.geometry.point.Point at 0x2116ccfd208>]

# %%
sanfran_df = gdp.GeoDataFrame(sanfran_df,#Specify our data
                         crs = crs,#specify our coordinate reference system
                         geometry = geometry)#Specify the geometry list we created
sanfran_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude  \
# 0                 368              -122.419622               37.785434
# 1                 104              -122.390833               37.767045
# 2                  49              -122.394989               37.780760
# 3                 323              -122.405950               37.798014
# 4                   5              -122.408445               37.783899
# ..                ...                      ...                     ...
# 171               361              -122.385655               37.739853
# 172               359              -122.398963               37.730168
# 173               413              -122.447723               37.720555
# 174               344              -122.396292               37.766349
# 175               367              -122.473658               37.771104
#
#                                          geometry
# 0    POINT (-122.4196216464043 37.78543382786823)
# 1    POINT (-122.3908334970474 37.76704457969368)
# 2                 POINT (-122.3949894 37.7807601)
# 3    POINT (-122.4059504270553 37.79801364395978)
# 4    POINT (-122.4084448814392 37.78389935708493)
# ..                                            ...
# 171  POINT (-122.3856554925442 37.73985301798412)
# 172  POINT (-122.3989632725716 37.73016750815088)
# 173  POINT (-122.4477231502533 37.72055498872064)
# 174  POINT (-122.3962917923927 37.76634858593739)
# 175                 POINT (-122.473658 37.771104)
#
# [176 rows x 4 columns]

# %%
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax, alpha = 0.4)

sanfran_df.plot(ax = ax, markersize = 20, color = "green", marker = "o", label = "Start Station Mil",alpha=0.99)
#test.plot(ax = ax, markersize = 20, color = "blue", marker = "^", label = "Start Station Mil",alpha=0.99)
#ax.margins(x=0.25, y=-.10)   # Values in (-0.5, 0.0) zooms in to center
plt.legend(prop={'size': 15})

# %%
#Query our data
con = sqlite3.connect("bikeshare.db")
oakland_df = sql.read_sql('SELECT DISTINCT start_station_id, start_station_longitude, start_station_latitude from bike_share where start_station_longitude between -122.35 and -122.10 and start_station_longitude like "-122%"', con)
oakland_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude
# 0                 249              -122.253253               37.858473
# 1                 160              -122.294837               37.805318
# 2                 259              -122.299371               37.866249
# 3                 243              -122.254337               37.869360
# 4                 267              -122.253569               37.861804
# ..                ...                      ...                     ...
# 123               174              -122.264004               37.836801
# 124               170              -122.261351               37.844493
# 125               234              -122.225400               37.778058
# 126               228              -122.217728               37.779930
# 127               224              -122.239305               37.784855
#
# [128 rows x 3 columns]

# %%
#Import our shape file
streetmap = gdp.read_file('shape/oakland/geo_export_a8aad267-4123-4b77-b2b3-58eea2d8c754.shp')

# %%
#Plot our shape file
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax)

# %%
#Read in the training data-set
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(oakland_df["start_station_longitude"], oakland_df["start_station_latitude"])]
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x211695438c8>,
#  <shapely.geometry.point.Point at 0x2116d8b11c8>,
#  <shapely.geometry.point.Point at 0x21169543b88>]

# %%
oakland_df = gdp.GeoDataFrame(oakland_df,#Specify our data
                         crs = crs,#specify our coordinate reference system
                         geometry = geometry)#Specify the geometry list we created
oakland_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude  \
# 0                 249              -122.253253               37.858473
# 1                 160              -122.294837               37.805318
# 2                 259              -122.299371               37.866249
# 3                 243              -122.254337               37.869360
# 4                 267              -122.253569               37.861804
# ..                ...                      ...                     ...
# 123               174              -122.264004               37.836801
# 124               170              -122.261351               37.844493
# 125               234              -122.225400               37.778058
# 126               228              -122.217728               37.779930
# 127               224              -122.239305               37.784855
#
#                                          geometry
# 0                 POINT (-122.2532529 37.8584732)
# 1                 POINT (-122.2948365 37.8053183)
# 2                  POINT (-122.2993708 37.866249)
# 3                 POINT (-122.2543374 37.8693603)
# 4                 POINT (-122.2535687 37.8618037)
# ..                                            ...
# 123               POINT (-122.2640037 37.8368013)
# 124                POINT (-122.261351 37.8444927)
# 125                   POINT (-122.2254 37.778058)
# 126                 POINT (-122.2177284 37.77993)
# 127  POINT (-122.2393047809601 37.78485466229441)
#
# [128 rows x 4 columns]

# %%
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax, alpha = 0.4)

oakland_df.plot(ax = ax, markersize = 20, color = "green", marker = "o", label = "Start Station Mil",alpha=0.99)
#test.plot(ax = ax, markersize = 20, color = "blue", marker = "^", label = "Start Station Mil",alpha=0.99)
#ax.margins(x=0.25, y=-.10)   # Values in (-0.5, 0.0) zooms in to center
plt.legend(prop={'size': 15})

# %%
#Query our data
con = sqlite3.connect("bikeshare.db")
oakland_df = sql.read_sql('SELECT distinct start_station_id, start_station_latitude, start_station_longitude from bike_share', con)
oakland_df
# Out:
#      start_station_id  start_station_latitude  start_station_longitude
# 0                 249               37.858473              -122.253253
# 1                 368               37.785434              -122.419622
# 2                 104               37.767045              -122.390833
# 3                 327               37.332039              -121.881766
# 4                  49               37.780760              -122.394989
# ..                ...                     ...                      ...
# 372               391               37.355030              -121.904436
# 373               421               37.360001              -121.878778
# 374               344               37.766349              -122.396292
# 375               408               45.510000               -73.570000
# 376               367               37.771104              -122.473658
#
# [377 rows x 3 columns]

# %%
gmaps.configure(api_key='AIzaSyCstm00Tu0M1HJeMANTwnvyj0nQYHOgyhE')

latitude_list = oakland_df.start_station_latitude
longitude_list = oakland_df.start_station_longitude

new_york_coordinates = (37.8187908,-122.2644687)
streetmap = gmaps.figure(center=new_york_coordinates, zoom_level=12)
streetmap
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Import gmplot library.
from gmplot import *

latitude_list = oakland_df.start_station_latitude
longitude_list = oakland_df.start_station_longitude

gmap=gmplot.GoogleMapPlotter(37.8187908,-122.2644687, 14)
gmap.scatter(latitude_list, longitude_list, '#164C05',size = 30,marker = False) 


gmap.apikey = "AIzaSyCstm00Tu0M1HJeMANTwnvyj0nQYHOgyhE"

# Location where you want to save your file.

#gmap.draw( 'wtf.html' )

# %%
import IPython
IPython.display.HTML(filename='wtf.html')
# Out:
# <html>
# <head>
# <meta name="viewport" content="initial-scale=1.0, user-scalable=no" />
# <meta http-equiv="content-type" content="text/html; charset=UTF-8"/>
# <title>Google Maps - pygmaps </title>
# <script type="text/javascript" src="https://maps.googleapis.com/maps/api/js?libraries=visualization&sensor=true_or_false&key=AIzaSyCstm00Tu0M1HJeMANTwnvyj0nQYHOgyhE"></script>
# <script type="text/javascript">
# 	function initialize() {
# 		var centerlatlng = new google.maps.LatLng(37.818791, -122.264469);
# 		var myOptions = {
# 			zoom: 14,
# 			center: centerlatlng,
# 			mapTypeId: google.maps.MapTypeId.ROADMAP
# 		};
# 		var map = new google.maps.Map(document.getElementById("map_canvas"), myOptions);
#
# var coords = [
# new google.maps.LatLng(37.858563, -122.253253),
# new google.maps.LatLng(37.858562, -122.253273),
# new google.maps.LatLng(37.858558, -122.253292),
# new google.maps.LatLng(37.858551, -122.253310),
# new google.maps.LatLng(37.858542, -122.253326),
# new google.maps.LatLng(37.858531, -122.253340),
# new google.maps.LatLng(37.858518, -122.253351),
# new google.maps.LatLng(37.858504, -122.253360),
# new google.maps.LatLng(37.858489, -122.253365),
# new google.maps.LatLng(37.858473, -122.253367),
# new google.maps.LatLng(37.858458, -122.253365),
# new google.maps.LatLng(37.858442, -122.253360),
# new google.maps.LatLng(37.858428, -122.253351),
# new google.maps.LatLng(37.858415, -122.253340),
# new google.maps.LatLng(37.858404, -122.253326),
# new google.maps.LatLng(37.858395, -122.253310),
# new google.maps.LatLng(37.858389, -122.253292),
# new google.maps.LatLng(37.858385, -122.253273),
# new google.maps.LatLng(37.858383, -122.253253),
# new google.maps.LatLng(37.858385, -122.253233),
# new google.maps.LatLng(37.858389, -122.253214),
# new google.maps.LatLng(37.858395, -122.253196),
# new google.maps.LatLng(37.858404, -122.253180),
# new google.maps.LatLng(37.858415, -122.253166),
# new google.maps.LatLng(37.858428, -122.253154),
# new google.maps.LatLng(37.858442, -122.253146),
# new google.maps.LatLng(37.858458, -122.253141),
# new google.maps.LatLng(37.858473, -122.253139),
# new google.maps.LatLng(37.858489, -122.253141),
# new google.maps.LatLng(37.858504, -122.253146),
# new google.maps.LatLng(37.858518, -122.253154),
# new google.maps.LatLng(37.858531, -122.253166),
# new google.maps.LatLng(37.858542, -122.253180),
# new google.maps.LatLng(37.858551, -122.253196),
# new google.maps.LatLng(37.858558, -122.253214),
# new google.maps.LatLng(37.858562, -122.253233),
# ];
#
# var polygon = new google.maps.Polygon({
# clickable: false,
# geodesic: true,
# fillColor: "#164C05",
# fillOpacity: 0.300000,
# paths: coords,
# strokeColor: "#164C05",
# strokeOpacity: 1.000000,
# strokeWeight: 1
# });
#
# polygon.setMap(map);
#
#
# var coords = [
# new google.maps.LatLng(37.805408, -122.294837),
# new google.maps.LatLng(37.805407, -122.294856),
# new google.maps.LatLng(37.805403, -122.294875),
# new google.maps.LatLng(37.805396, -122.294893),
# new google.maps.LatLng(37.805387, -122.294910),
# new google.maps.LatLng(37.805376, -122.294924),
# new google.maps.LatLng(37.805363, -122.294935),
# new google.maps.LatLng(37.805349, -122.294943),
# new google.maps.LatLng(37.805334, -122.294948),
# new google.maps.LatLng(37.805318, -122.294950),
# new google.maps.LatLng(37.805303, -122.294948),
# new google.maps.LatLng(37.805288, -122.294943),
# new google.maps.LatLng(37.805273, -122.294935),
# new google.maps.LatLng(37.805261, -122.294924),
# new google.maps.LatLng(37.805249, -122.294910),
# new google.maps.LatLng(37.805241, -122.294893),
# new google.maps.LatLng(37.805234, -122.294875),
# new google.maps.LatLng(37.805230, -122.294856),
# new google.maps.LatLng(37.805228, -122.294837),
# new google.maps.LatLng(37.805230, -122.294817),
# new google.maps.LatLng(37.805234, -122.294798),
# new google.maps.LatLng(37.805241, -122.294780),
# new google.maps.LatLng(37.805249, -122.294763),
# new google.maps.LatLng(37.805261, -122.294749),
# new google.maps.LatLng(37.805273, -122.294738),
# new google.maps.LatLng(37.805288, -122.294730),
# new google.maps.LatLng(37.805303, -122.294725),
# new google.maps.LatLng(37.805318, -122.294723),
# new google.maps.LatLng(37.805334, -122.294725),
# new google.maps.LatLng(37.805349, -122.294730),
# new google.maps.LatLng(37.805363, -122.294738),
# new google.maps.LatLng(37.805376, -122.294749),
# new google.maps.LatLng(37.805387, -122.294763),
# new google.maps.LatLng(37.805396, -122.294780),
# new google.maps.LatLng(37.805403, -122.294798),
# new google.maps.LatLng(37.805407, -122.294817),
# ];
#
# var polygon = new google.maps.Polygon({
# clickable: false,
# geodesic: true,
# fillColor: "#164C05",
# fillOpacity: 0.300000,
# paths: coords,
# strokeColor: "#164C05",
# strokeOpacity: 1.000000,
# strokeWeight: 1
# });
#
# polygon.setMap(map);
#
#
# var coords = [
# new google.maps.LatLng(37.866339, -122.299371),
# new google.maps.LatLng(37.866337, -122.299391),
# new google.maps.LatLng(37.866333, -122.299410),
# new google.maps.LatLng(37.866327, -122.299428),
# new google.maps.LatLng(37.866318, -122.299444),
# new google.maps.LatLng(37.866307, -122.299458),
# new google.maps.LatLng(37.866294, -122.299469),
# new google.maps.LatLng(37.866280, -122.299478),
# new google.maps.LatLng(37.866265, -122.299483),
# new google.maps.LatLng(37.866249, -122.299485),
# new google.maps.LatLng(37.866233, -122.299483),
# new google.maps.LatLng(37.866218, -122.299478),
# new google.maps.LatLng(37.866204, -122.299469),
# new google.maps.LatLng(37.866191, -122.299458),
# new google.maps.LatLng(37.866180, -122.299444),
# new google.maps.LatLng(37.866171, -122.299428),
# new google.maps.LatLng(37.866165, -122.299410),
# new google.maps.LatLng(37.866161, -122.299391),
# new google.maps.LatLng(37.866159, -122.299371),
# new google.maps.LatLng(37.866161, -122.299351),
# new google.maps.LatLng(37.866165, -122.299332),
# new google.maps.LatLng(37.866171, -122.299314),
# new google.maps.LatLng(37.866180, -122.299298),
# new google.maps.LatLng(37.866191, -122.299284),
# new google.maps.LatLng(37.866204, -122.299272),
# new google.maps.LatLng(37.866218, -122.299264),
# new google.maps.LatLng(37.866233, -122.299259),
# new google.maps.LatLng(37.866249, -122.299257),
# new google.maps.LatLng(37.866265, -122.299259),
# new google.maps.LatLng(37.866280, -122.299264),
# new google.maps.LatLng(37.866294, -122.299272),
# new google.maps.LatLng(37.866307, -122.299284),
# new google.maps.LatLng(37.866318, -122.299298),
# new google.maps.LatLng(37.866327, -122.299314),
# new google.maps.LatLng(37.866333, -122.299332),
# new google.maps.LatLng(37.866337, -122.299351),
# ];
#
# var polygon = new google.maps.Polygon({
# clickable: false,
# geodesic: true,
# fillColor: "#164C05",
# fillOpacity: 0.300000,
# paths: coords,
# strokeColor: "#164C05",
# strokeOpacity: 1.000000,
# strokeWeight: 1
# });
#
# polygon.setMap(map);
#
#
# var coords = [
# new google.maps.LatLng(37.869450, -122.254337),
# new google.maps.LatLng(37.869449, -122.254357),
# new google.maps.LatLng(37.869445, -122.254376),
# new google.maps.LatLng(37.869438, -122.254394),
# new google.maps.LatLng(37.869429, -122.254411),
# new google.maps.LatLng(37.869418, -122.254425),
# new google.maps.LatLng(37.869405, -122.254436),
# new google.maps.LatLng(37.869391, -122.254444),
# new google.maps.LatLng(37.869376, -122.254449),
# new google.maps.LatLng(37.869360, -122.254451),
# new google.maps.LatLng(37.869345, -122.254449),
# new google.maps.LatLng(37.869330, -122.254444),
# new google.maps.LatLng(37.869315, -122.254436),
# new google.maps.LatLng(37.869303, -122.254425),
# new google.maps.LatLng(37.869291, -122.254411),
# new google.maps.LatLng(37.869283, -122.254394),
# new google.maps.LatLng(37.869276, -122.254376),
# new google.maps.LatLng(37.869272, -122.254357),
# new google.maps.LatLng(37.869270, -122.254337),
# new google.maps.LatLng(37.869272, -122.254318),
# new google.maps.LatLng(37.869276, -122.254298),
# new google.maps.LatLng(37.869283, -122.254281),
# new google.maps.LatLng(37.869291, -122.254264),
# new google.maps.LatLng(37.869303, -122.254250),
# new google.maps.LatLng(37.869315, -122.254239),
# new google.maps.LatLng(37.869330, -122.254230),
# new google.maps.LatLng(37.869345, -122.254225),
# new google.maps.LatLng(37.869360, -122.254224),
# new google.maps.LatLng(37.869376,

# %%
#Import our shape file
streetmap = gdp.read_file('shape/oakland/geo_export_a8aad267-4123-4b77-b2b3-58eea2d8c754.shp')

# %%
#Plot our shape file
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax)

# %%
#Read in the training data-set
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(oakland_df["start_station_longitude"], oakland_df["start_station_latitude"])]
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x211695438c8>,
#  <shapely.geometry.point.Point at 0x2116d8b11c8>,
#  <shapely.geometry.point.Point at 0x21169543b88>]

# %%
oakland_df = gdp.GeoDataFrame(oakland_df,#Specify our data
                         crs = crs,#specify our coordinate reference system
                         geometry = geometry)#Specify the geometry list we created
oakland_df
# Out:
#      start_station_id  start_station_longitude  start_station_latitude  \
# 0                 249              -122.253253               37.858473
# 1                 160              -122.294837               37.805318
# 2                 259              -122.299371               37.866249
# 3                 243              -122.254337               37.869360
# 4                 267              -122.253569               37.861804
# ..                ...                      ...                     ...
# 123               174              -122.264004               37.836801
# 124               170              -122.261351               37.844493
# 125               234              -122.225400               37.778058
# 126               228              -122.217728               37.779930
# 127               224              -122.239305               37.784855
#
#                                          geometry
# 0                 POINT (-122.2532529 37.8584732)
# 1                 POINT (-122.2948365 37.8053183)
# 2                  POINT (-122.2993708 37.866249)
# 3                 POINT (-122.2543374 37.8693603)
# 4                 POINT (-122.2535687 37.8618037)
# ..                                            ...
# 123               POINT (-122.2640037 37.8368013)
# 124                POINT (-122.261351 37.8444927)
# 125                   POINT (-122.2254 37.778058)
# 126                 POINT (-122.2177284 37.77993)
# 127  POINT (-122.2393047809601 37.78485466229441)
#
# [128 rows x 4 columns]

# %%
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax, alpha = 0.4)

oakland_df.plot(ax = ax, markersize = 20, color = "green", marker = "o", label = "Start Station Mil",alpha=0.99)
#test.plot(ax = ax, markersize = 20, color = "blue", marker = "^", label = "Start Station Mil",alpha=0.99)
#ax.margins(x=0.25, y=-.10)   # Values in (-0.5, 0.0) zooms in to center
plt.legend(prop={'size': 15})

# %%
#Query our data
con = sqlite3.connect("bikeshare.db")
oakland_df = sql.read_sql('SELECT DISTINCT start_station_id, start_station_longitude, start_station_latitude from bike_share where start_station_longitude between -122.35 and -122.10 and start_station_longitude like "-122%"', con)
oakland_df

#Import our shape file
streetmap = gdp.read_file('shape/oakland/geo_export_a8aad267-4123-4b77-b2b3-58eea2d8c754.shp')

#Plot our shape file
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax)

#Read in the training data-set
crs = {'init': 'epsg:4326'}

geometry = [Point(xy) for xy in zip(oakland_df["start_station_longitude"], oakland_df["start_station_latitude"])]
geometry[:3]

oakland_df = gdp.GeoDataFrame(oakland_df,#Specify our data
                         crs = crs,#specify our coordinate reference system
                         geometry = geometry)#Specify the geometry list we created
oakland_df

fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax, alpha = 0.4)

oakland_df.plot(ax = ax, markersize = 20, color = "green", marker = "o", label = "Start Station Mil",alpha=0.99)
#test.plot(ax = ax, markersize = 20, color = "blue", marker = "^", label = "Start Station Mil",alpha=0.99)
#ax.margins(x=0.25, y=-.10)   # Values in (-0.5, 0.0) zooms in to center
plt.legend(prop={'size': 15})
