# %% [markdown]
# ## Exploratory Data Visualization

# %%
import sqlite3
import pandas.io.sql as sql
import pandas as pd
import seaborn as sns
import geopandas as gdp
from shapely.geometry import Point,Polygon
import csv
import matplotlib.pyplot as plt

# %% [markdown]
# ### Using SQL for Advanced Querying

# %%
#A script to create and import a .csv into sqlite3
'''con = sqlite3.connect("bikeshare.db")
cur = con.cursor()
cur.execute("CREATE TABLE bike_share (id INTEGER PRIMARY KEY,duration_sec int64(50),"
            "start_time datetime,end_time datetime,start_station_id int64,start_station_name varchar(255),start_station_latitude float(1,10),start_station_longitude float(1,10),end_station_id int64(50),end_station_name varchar(255),end_station_latitude float(1,10),end_station_longitude float(1,10),bike_id int64,user_type varchar(255),member_birth_year int,member_gender varchar(255),bike_share_for_all_trip varchar(255) );")

with open('201908-baywheels-tripdata.csv','r', encoding='utf-8') as fin: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['duration_sec'],i['start_time'],i['end_time'],i['start_station_id'],i['start_station_name'],i['start_station_latitude'],i['start_station_longitude'],i['end_station_id'],i['end_station_name'],i['end_station_latitude'],i['end_station_longitude'],i['bike_id'],i['user_type'],i['member_birth_year'],i['member_gender'],i['bike_share_for_all_trip']) for i in dr]

cur.executemany("INSERT INTO bike_share (duration_sec,start_time,end_time,start_station_id,start_station_name,start_station_latitude,start_station_longitude,end_station_id,end_station_name,end_station_latitude,end_station_longitude,bike_id,user_type,member_birth_year,member_gender,bike_share_for_all_trip) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?);", to_db)
con.commit()'''
# Out:
# 'con = sqlite3.connect("bikeshare.db")\ncur = con.cursor()\ncur.execute("CREATE TABLE bike_share (id INTEGER PRIMARY KEY,duration_sec int64(50),"\n            "start_time datetime,end_time datetime,start_station_id int64,start_station_name varchar(255),start_station_latitude float(1,10),start_station_longitude float(1,10),end_station_id int64(50),end_station_name varchar(255),end_station_latitude float(1,10),end_station_longitude float(1,10),bike_id int64,user_type varchar(255),member_birth_year int,member_gender varchar(255),bike_share_for_all_trip varchar(255) );")\n\nwith open(\'201908-baywheels-tripdata.csv\',\'r\', encoding=\'utf-8\') as fin: # `with` statement available in 2.5+\n    # csv.DictReader uses first line in file for column headings by default\n    dr = csv.DictReader(fin) # comma is default delimiter\n    to_db = [(i[\'duration_sec\'],i[\'start_time\'],i[\'end_time\'],i[\'start_station_id\'],i[\'start_station_name\'],i[\'start_station_latitude\'],i[\'start_station_longitude\'],i[\'end_station_id\'],i[\'end_station_name\'],i[\'end_station_latitude\'],i[\'end_station_longitude\'],i[\'bike_id\'],i[\'user_type\'],i[\'member_birth_year\'],i[\'member_gender\'],i[\'bike_share_for_all_trip\']) for i in dr]\n\ncur.executemany("INSERT INTO bike_share (duration_sec,start_time,end_time,start_station_id,start_station_name,start_station_latitude,start_station_longitude,end_station_id,end_station_name,end_station_latitude,end_station_longitude,bike_id,user_type,member_birth_year,member_gender,bike_share_for_all_trip) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?);", to_db)\ncon.commit()'

# %% [markdown]
# #### Let’s check our data all of our data and then run another query to see if we have any duplicated user ID’s

# %%
#Query all of our data
con = sqlite3.connect("bikeshare.db")
df = sql.read_sql('SELECT * from bike_share', con)
df
# Out:
#             id  duration_sec                start_time  \
# 0            1         68145  2019-08-31 21:27:42.2530
# 1            2         53216  2019-08-31 22:34:17.5120
# 2            3         53182  2019-08-31 22:34:49.9420
# 3            4         75682  2019-08-31 14:22:02.2780
# 4            5         30849  2019-08-31 18:47:08.0570
# ...        ...           ...                       ...
# 210558  210559           728  2019-08-01 00:07:37.0390
# 210559  210560           761  2019-08-01 00:06:23.8300
# 210560  210561           331  2019-08-01 00:08:28.7570
# 210561  210562           111  2019-08-01 00:11:02.5820
# 210562  210563           255  2019-08-01 00:04:27.9530
#
#                         end_time  start_station_id  \
# 0       2019-09-01 16:23:27.4920               249
# 1       2019-09-01 13:21:13.9310               368
# 2       2019-09-01 13:21:12.4570               368
# 3       2019-09-01 11:23:24.5110               104
# 4       2019-09-01 03:21:17.6970               327
# ...                          ...               ...
# 210558  2019-08-01 00:19:45.7760                67
# 210559  2019-08-01 00:19:05.5500               151
# 210560  2019-08-01 00:14:00.1350                30
# 210561  2019-08-01 00:12:54.1340               183
# 210562  2019-08-01 00:08:43.3370               104
#
#                                        start_station_name  \
# 0                               Russell St at College Ave
# 1                                    Myrtle St at Polk St
# 2                                    Myrtle St at Polk St
# 3                                       4th St at 16th St
# 4                               5th St at San Salvador St
# ...                                                   ...
# 210558  San Francisco Caltrain Station 2  (Townsend St...
# 210559                               53rd St at Hollis St
# 210560     San Francisco Caltrain (Townsend St at 4th St)
# 210561                           Telegraph Ave at 19th St
# 210562                                  4th St at 16th St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.858473              -122.253253             247
# 1                    37.785434              -122.419622              78
# 2                    37.785434              -122.419622              78
# 3                    37.767045              -122.390833             126
# 4                    37.332039              -121.881766             327
# ...                        ...                      ...             ...
# 210558               37.776639              -122.395526              17
# 210559               37.836182              -122.287180             159
# 210560               37.776598              -122.395282              62
# 210561               37.808702              -122.269927             180
# 210562               37.767045              -122.390833             104
#
#                                         end_station_name  \
# 0                              Fulton St at Bancroft Way
# 1                                    Folsom St at 9th St
# 2                                    Folsom St at 9th St
# 3                                            Esprit Park
# 4                              5th St at San Salvador St
# ...                                                  ...
# 210558  Embarcadero BART Station (Beale St at Market St)
# 210559                              24th St at Market St
# 210560                       Victoria Manalo Draves Park
# 210561                          Telegraph Ave at 23rd St
# 210562                                 4th St at 16th St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0                  37.867789            -122.265896     3112    Customer
# 1                  37.773717            -122.411647     2440    Customer
# 2                  37.773717            -122.411647     9743    Customer
# 3                  37.761634            -122.390648    11418  Subscriber
# 4                  37.332039            -121.881766     1553    Customer
# ...                      ...                    ...      ...         ...
# 210558             37.792251            -122.397086     2500  Subscriber
# 210559             37.816060            -122.278244      613  Subscriber
# 210560             37.777791            -122.406432     2904  Subscriber
# 210561             37.812678            -122.268773     1910  Subscriber
# 210562             37.767045            -122.390833     3703  Subscriber
#
#        member_birth_year member_gender bike_share_for_all_trip
# 0                                                           No
# 1                   1993        Female                      No
# 2                   1995          Male                      No
# 3                   1993        Female                      No
# 4                                                           No
# ...                  ...           ...                     ...
# 210558              1983          Male                      No
# 210559              1982        Female                      No
# 210560              1994          Male                      No
# 210561              1993          Male                      No
# 210562              1990          Male                      No
#
# [210563 rows x 17 columns]

# %%
#Check distinct ID
con = sqlite3.connect("bikeshare.db")
dupes = sql.read_sql('SELECT DISTINCT id from bike_share ', con)
dupes
# Out:
#             id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 210558  210559
# 210559  210560
# 210560  210561
# 210561  210562
# 210562  210563
#
# [210563 rows x 1 columns]

# %% [markdown]
# After doing a check we know there are no duplicated records both match (210563) rows

# %%
#Checking our data types
df.dtypes
# Out:
# id                           int64
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id             int64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id               int64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year           object
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %%
#Check the shape of the data
df.shape
# Out:
# (210563, 17)

# %%
#Fix the timestamp issue when converting to pandas.
df.start_time = pd.to_datetime(df.start_time)
df.end_time = pd.to_datetime(df.end_time)
df.dtypes
# Out:
# id                                  int64
# duration_sec                        int64
# start_time                 datetime64[ns]
# end_time                   datetime64[ns]
# start_station_id                    int64
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_station_id                      int64
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# bike_id                             int64
# user_type                          object
# member_birth_year                  object
# member_gender                      object
# bike_share_for_all_trip            object
# dtype: object

# %% [markdown]
# Run a query where birth_year is not null.

# %%
#Query the data where birth_year not null
birth = sql.read_sql('SELECT * from bike_share where member_birth_year != "" ', con)
birth
# Out:
#             id  duration_sec                start_time  \
# 0            2         53216  2019-08-31 22:34:17.5120
# 1            3         53182  2019-08-31 22:34:49.9420
# 2            4         75682  2019-08-31 14:22:02.2780
# 3            7          8959  2019-08-31 22:44:38.2130
# 4           11          1624  2019-08-31 23:55:17.3900
# ...        ...           ...                       ...
# 170769  210559           728  2019-08-01 00:07:37.0390
# 170770  210560           761  2019-08-01 00:06:23.8300
# 170771  210561           331  2019-08-01 00:08:28.7570
# 170772  210562           111  2019-08-01 00:11:02.5820
# 170773  210563           255  2019-08-01 00:04:27.9530
#
#                         end_time  start_station_id  \
# 0       2019-09-01 13:21:13.9310               368
# 1       2019-09-01 13:21:12.4570               368
# 2       2019-09-01 11:23:24.5110               104
# 3       2019-09-01 01:13:57.2480               323
# 4       2019-09-01 00:22:22.1320               276
# ...                          ...               ...
# 170769  2019-08-01 00:19:45.7760                67
# 170770  2019-08-01 00:19:05.5500               151
# 170771  2019-08-01 00:14:00.1350                30
# 170772  2019-08-01 00:12:54.1340               183
# 170773  2019-08-01 00:08:43.3370               104
#
#                                        start_station_name  \
# 0                                    Myrtle St at Polk St
# 1                                    Myrtle St at Polk St
# 2                                       4th St at 16th St
# 3                                      Broadway at Kearny
# 4                                Julian St at The Alameda
# ...                                                   ...
# 170769  San Francisco Caltrain Station 2  (Townsend St...
# 170770                               53rd St at Hollis St
# 170771     San Francisco Caltrain (Townsend St at 4th St)
# 170772                           Telegraph Ave at 19th St
# 170773                                  4th St at 16th St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.785434              -122.419622              78
# 1                    37.785434              -122.419622              78
# 2                    37.767045              -122.390833             126
# 3                    37.798014              -122.405950               8
# 4                    37.332233              -121.912516             276
# ...                        ...                      ...             ...
# 170769               37.776639              -122.395526              17
# 170770               37.836182              -122.287180             159
# 170771               37.776598              -122.395282              62
# 170772               37.808702              -122.269927             180
# 170773               37.767045              -122.390833             104
#
#                                         end_station_name  \
# 0                                    Folsom St at 9th St
# 1                                    Folsom St at 9th St
# 2                                            Esprit Park
# 3                          The Embarcadero at Vallejo St
# 4                               Julian St at The Alameda
# ...                                                  ...
# 170769  Embarcadero BART Station (Beale St at Market St)
# 170770                              24th St at Market St
# 170771                       Victoria Manalo Draves Park
# 170772                          Telegraph Ave at 23rd St
# 170773                                 4th St at 16th St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0                  37.773717            -122.411647     2440    Customer
# 1                  37.773717            -122.411647     9743    Customer
# 2                  37.761634            -122.390648    11418  Subscriber
# 3                  37.799953            -122.398525     3028    Customer
# 4                  37.332233            -121.912516    10567  Subscriber
# ...                      ...                    ...      ...         ...
# 170769             37.792251            -122.397086     2500  Subscriber
# 170770             37.816060            -122.278244      613  Subscriber
# 170771             37.777791            -122.406432     2904  Subscriber
# 170772             37.812678            -122.268773     1910  Subscriber
# 170773             37.767045            -122.390833     3703  Subscriber
#
#         member_birth_year member_gender bike_share_for_all_trip
# 0                    1993        Female                      No
# 1                    1995          Male                      No
# 2                    1993        Female                      No
# 3                    1970        Female                      No
# 4                    1969          Male                     Yes
# ...                   ...           ...                     ...
# 170769               1983          Male                      No
# 170770               1982        Female                      No
# 170771               1994          Male                      No
# 170772               1993          Male                      No
# 170773               1990          Male                      No
#
# [170774 rows x 17 columns]

# %% [markdown]
# Let’s see what genders are using the bike share program most.

# %%
#Query our data and store it into a pandas dataframe
gender = sql.read_sql('SELECT member_gender, COUNT(member_gender) as count FROM bike_share WHERE member_gender !="" GROUP BY member_gender ORDER BY COUNT(member_gender) DESC', con)
gender
# Out:
#   member_gender   count
# 0          Male  128285
# 1        Female   40054
# 2         Other    2438

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="member_gender", y="count", data=gender,label="Total", color="#79B8D5")

plt.xlabel('')
plt.ylabel('')
plt.title("Bike Share Genders")
# Out:
# Text(0.5, 1.0, 'Bike Share Genders')

# %%
#Query our data and store it into a pandas dataframe
user = sql.read_sql('SELECT user_type, COUNT(user_type) as count FROM bike_share WHERE user_type !="" GROUP BY user_type ORDER BY COUNT(user_type) DESC', con)
user
# Out:
#     user_type   count
# 0  Subscriber  164928
# 1    Customer   45635

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="user_type", y="count", data=user,label="Total", color="#D4DF8C")

plt.xlabel('')
plt.ylabel('')
plt.title("Bike Share Subcribers vs Non Subscribers")
# Out:
# Text(0.5, 1.0, 'Bike Share Subcribers vs Non Subscribers')

# %%
#Query our data and store it into a pandas dataframe
pop_bike = sql.read_sql('SELECT bike_id, COUNT(bike_id) as count FROM bike_share WHERE bike_id !="" GROUP BY bike_id ORDER BY COUNT(bike_id) DESC', con)
pop_bike20 = pop_bike.head(20)
pop_bike20
# Out:
#     bike_id  count
# 0      9477    175
# 1      3028    166
# 2      9467    166
# 3      1124    162
# 4      3589    159
# 5      1624    156
# 6       954    153
# 7      9555    152
# 8      3089    150
# 9      3386    149
# 10     3744    149
# 11     2293    148
# 12     2526    148
# 13     1204    147
# 14     2174    147
# 15     3491    147
# 16     1554    146
# 17     2771    146
# 18     2994    146
# 19     3135    146

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="bike_id", y="count", data=pop_bike20,label="Total", color="#A4DF8C")

plt.xlabel('')
plt.ylabel('Count')
plt.title('Most Frequently Used Bikes')
#plt.savefig('name_here')
# Out:
# Text(0.5, 1.0, 'Most Frequently Used Bikes')

# %%
df.head()
# Out:
#    id  duration_sec              start_time                end_time  \
# 0   1         68145 2019-08-31 21:27:42.253 2019-09-01 16:23:27.492
# 1   2         53216 2019-08-31 22:34:17.512 2019-09-01 13:21:13.931
# 2   3         53182 2019-08-31 22:34:49.942 2019-09-01 13:21:12.457
# 3   4         75682 2019-08-31 14:22:02.278 2019-09-01 11:23:24.511
# 4   5         30849 2019-08-31 18:47:08.057 2019-09-01 03:21:17.697
#
#    start_station_id         start_station_name  start_station_latitude  \
# 0               249  Russell St at College Ave               37.858473
# 1               368       Myrtle St at Polk St               37.785434
# 2               368       Myrtle St at Polk St               37.785434
# 3               104          4th St at 16th St               37.767045
# 4               327  5th St at San Salvador St               37.332039
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0              -122.253253             247  Fulton St at Bancroft Way
# 1              -122.419622              78        Folsom St at 9th St
# 2              -122.419622              78        Folsom St at 9th St
# 3              -122.390833             126                Esprit Park
# 4              -121.881766             327  5th St at San Salvador St
#
#    end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0             37.867789            -122.265896     3112    Customer
# 1             37.773717            -122.411647     2440    Customer
# 2             37.773717            -122.411647     9743    Customer
# 3             37.761634            -122.390648    11418  Subscriber
# 4             37.332039            -121.881766     1553    Customer
#
#   member_birth_year member_gender bike_share_for_all_trip
# 0                                                      No
# 1              1993        Female                      No
# 2              1995          Male                      No
# 3              1993        Female                      No
# 4                                                      No

# %% [markdown]
# Let’s make some histograms and scatter plots for areas of interest.

# %%
#Age group using the bike share program
birth.hist(column='member_birth_year');

# %%
#Age group using the bike share program
birth.plot(kind='scatter', x='member_birth_year', y='duration_sec');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Which bikes are being used the most?
df.hist(column='bike_id');

# %%
#How long are bikes being used?
df.plot(kind='scatter', x='bike_id', y='duration_sec');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#What beginning stations are popular?
df.hist(column='start_station_id');

# %%
#Start station vs member birth year
birth.plot(kind='scatter', x='start_station_id', y='member_birth_year');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df.hist(column='end_station_id');

# %%
#Start station vs member birth year
birth.plot(kind='scatter', x='end_station_id', y='member_birth_year');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Query our data and store it into a pandas dataframe
station = sql.read_sql('SELECT start_station_name, COUNT(start_station_name) as count FROM bike_share WHERE start_station_name !="" GROUP BY start_station_name ORDER BY COUNT(start_station_name) DESC', con)
pop_station = station.head(5)
unpop_station = station.tail(5)

# %%
#popular stations
pop_station
# Out:
#                                   start_station_name  count
# 0  San Francisco Caltrain Station 2  (Townsend St...   5196
# 1                                 Berry St at 4th St   4156
# 2  San Francisco Ferry Building (Harry Bridges Pl...   3714
# 3                               Market St at 10th St   3543
# 4   Montgomery St BART Station (Market St at 2nd St)   3092

# %%
#unpopular stations
unpop_station
# Out:
#                  start_station_name  count
# 372              Utah St at 24th St     11
# 373           1st St at Younger Ave      8
# 374  21st Ave at International Blvd      7
# 375                     MTL-ECO5-01      3
# 376                   16th St Depot      2

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="start_station_name", y="count", data=pop_station, label="Total", color="#5F9C46")

plt.xlabel('')
plt.ylabel('')
plt.title("Most Popular Starting Stations")
plt.savefig('popular_dog_names')
plt.xticks(rotation=-70);

# %%
#create our bar chart
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="start_station_name", y="count", data=unpop_station, label="Total", color="#E7604D")

plt.xlabel('')
plt.ylabel('')
plt.title("Least Popular Starting Stations")
plt.xticks(rotation=-70);

# %%
df.head()
# Out:
#    id  duration_sec              start_time                end_time  \
# 0   1         68145 2019-08-31 21:27:42.253 2019-09-01 16:23:27.492
# 1   2         53216 2019-08-31 22:34:17.512 2019-09-01 13:21:13.931
# 2   3         53182 2019-08-31 22:34:49.942 2019-09-01 13:21:12.457
# 3   4         75682 2019-08-31 14:22:02.278 2019-09-01 11:23:24.511
# 4   5         30849 2019-08-31 18:47:08.057 2019-09-01 03:21:17.697
#
#    start_station_id         start_station_name  start_station_latitude  \
# 0               249  Russell St at College Ave               37.858473
# 1               368       Myrtle St at Polk St               37.785434
# 2               368       Myrtle St at Polk St               37.785434
# 3               104          4th St at 16th St               37.767045
# 4               327  5th St at San Salvador St               37.332039
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0              -122.253253             247  Fulton St at Bancroft Way
# 1              -122.419622              78        Folsom St at 9th St
# 2              -122.419622              78        Folsom St at 9th St
# 3              -122.390833             126                Esprit Park
# 4              -121.881766             327  5th St at San Salvador St
#
#    end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0             37.867789            -122.265896     3112    Customer
# 1             37.773717            -122.411647     2440    Customer
# 2             37.773717            -122.411647     9743    Customer
# 3             37.761634            -122.390648    11418  Subscriber
# 4             37.332039            -121.881766     1553    Customer
#
#   member_birth_year member_gender bike_share_for_all_trip
# 0                                                      No
# 1              1993        Female                      No
# 2              1995          Male                      No
# 3              1993        Female                      No
# 4                                                      No

# %%
df.boxplot(by ='bike_share_for_all_trip', column =['bike_id'], grid = False) ;

# %%
#Let's Check what other variables we can work with.
df.describe()
# Out:
#                   id  duration_sec  start_station_id  start_station_latitude  \
# count  210563.000000  210563.00000     210563.000000           210563.000000
# mean   105282.000000     833.51472        144.829481               37.770058
# std     60784.446703    1928.22378        120.128023                0.102810
# min         1.000000      61.00000          3.000000               37.311284
# 25%     52641.500000     376.00000         50.000000               37.770407
# 50%    105282.000000     593.00000        104.000000               37.780526
# 75%    157922.500000     914.00000        240.000000               37.795393
# max    210563.000000   85492.00000        459.000000               45.510000
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            210563.000000   210563.000000         210563.000000
# mean               -122.354407      140.921145             37.770268
# std                   0.217648      118.990674              0.102675
# min                -122.473658        3.000000             37.311284
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285       99.000000             37.780787
# 75%                -122.294837      233.000000             37.797280
# max                 -73.570000      459.000000             45.510000
#
#        end_station_longitude        bike_id
# count          210563.000000  210563.000000
# mean             -122.353604    4048.755897
# std                 0.217245    3639.124465
# min              -122.473658      12.000000
# 25%              -122.411306    1312.000000
# 50%              -122.397437    2629.000000
# 75%              -122.294837    9241.000000
# max               -73.570000   11945.000000

# %%
#creating a matrix to give us some ideas of what we could potentially plot.
pd.plotting.scatter_matrix(df, figsize=(16,16));
#df.iloc[:, 0:2]
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001B8682F0048> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     864     def draw(self, renderer):
#     865         self.set_sizes(self._sizes, self.figure.dpi)
# --> 866         Collection.draw(self, renderer)
#     867
#     868
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     327                 self._linewidths, self._linestyles,
#     328                 self._antialiaseds, self._urls,
# --> 329                 self._offset_position)
#     330
#     331         gc.restore()
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\path.py in vertices(self)
#     195         )
#     196
# --> 197     @property
#     198     def vertices(self):
#     199         """
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001B8683568B8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <D:\anaconda3\envs\Data Analysis Course\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     864     def draw(self, renderer):
#     865         self.set_sizes(self._sizes, self.figure.dpi)
# --> 866         Collection.draw(self, renderer)
#     867
#     868
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     327                 self._linewidths, self._linestyles,
#     328                 self._antialiaseds, self._urls,
# --> 329                 self._offset_position)
#     330
#     331         gc.restore()
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\path.py in vertices(self)
#     195         )
#     196
# --> 197     @property
#     198     def vertices(self):
#     199         """
#
# KeyboardInterrupt:

# %%
pd.plotting.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde');
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-af1f1285d14c> in <module>
# ----> 1 pd.plotting.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde');
#       2 #plt.show()
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\pandas\plotting\_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#     137         hist_kwds=hist_kwds,
#     138         range_padding=range_padding,
# --> 139         **kwds
#     140     )
#     141
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\pandas\plotting\_matplotlib\misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      67                     gkde = gaussian_kde(y)
#      68                     ind = np.linspace(y.min(), y.max(), 1000)
# ---> 69                     ax.plot(ind, gkde.evaluate(ind), **density_kwds)
#      70
#      71                 ax.set_xlim(boundaries_list[i])
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\scipy\stats\kde.py in evaluate(self, points)
#     257             for i in range(m):
#     258                 diff = scaled_dataset - scaled_points[:, i, newaxis]
# --> 259                 energy = sum(diff * diff, axis=0) / 2.0
#     260                 result[i] = sum(exp(-energy)*self.weights, axis=0)
#     261
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    2074
#    2075     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2076                           initial=initial)
#    2077
#    2078
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001B8682F0048> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2605                 artists.remove(spine)
#    2606
# -> 2607         self._update_title_position(renderer)
#    2608
#    2609         if not self.axison or inframe:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2547                     if (ax.xaxis.get_label_position() == 'top' or
#    2548                             ax.xaxis.get_ticks_position() in choices):
# -> 2549                         bb = ax.xaxis.get_tightbbox(renderer)
#    2550                     else:
#    2551                         bb = ax.get_window_extent(renderer)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1160             return
#    1161
# -> 1162         ticks_to_draw = self._update_ticks()
#    1163
#    1164         self._update_label_position(renderer)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#    1083         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1409         while len(self.majorTicks) < numticks:
#    1410             # Update the new tick label properties from the old.
# -> 1411             tick = self._get_tick(major=True)
#    1412             self.majorTicks.append(tick)
#    1413             tick.gridline.set_visible(self._gridOnMajor)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
# --> 160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
#     162         self.label2 = self._get_text2()
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\axis.py in _get_gridline(self)
#     493                           **self._grid_kw)
#     494         l.set_transform(self.axes.get_xaxis_transform(which='grid'))
# --> 495         l.get_path()._interpolation_steps = GRIDLINE_INTERPOLATION_STEPS
#     496         self._set_artist_props(l)
#     497
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     677             y = self._y
#     678
# --> 679         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     680         self._x, self._y = self._xy.T  # views
#     681
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001B8683568B8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <D:\anaconda3\envs\Data Analysis Course\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# D:\anaconda3\envs\Data Analysis Course\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
# --> 532                                self.figure.dpi, metadata=metadata)
#     533
#     534     def print_to_buffer(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ### <p>Observations within the scatter matrix:</p>
# <ol>
# <li>Member birth year is skewed right suggesting users are millennials and the younger generation are majority users of the program.</li>
# </ol>
# <ul>
# <li>Which age group is most prominent?</li>
# <li>What start stations are they using?</li>
# <li>What end stations are they using?</li>
# <li>Who uses the bike sharing more men vs women?</li>
# </ul>

# %% [markdown]
# ### Lets create user groups based on generation.
# <p>
# <li><em>Baby Boomers</em> between years 1946 – 1964</li>
#     <li><em>Generation X</em> between years 1965 – 1980</li>
#     <li><em>Millennials</em> between years 1981 – 1996</li>

# %%
#Query all of our data
con = sqlite3.connect("bikeshare.db")
birth_geo_df = sql.read_sql('SELECT * from bike_share where start_station_id != end_station_id order by duration_sec desc limit 10', con)
birth_geo_df
# Out:
#        id  duration_sec                start_time                  end_time  \
# 0  137529         85492  2019-08-11 16:19:56.2900  2019-08-12 16:04:48.8640
# 1   17400         85314  2019-08-28 09:11:09.3100  2019-08-29 08:53:03.7980
# 2  127106         85252  2019-08-12 19:41:21.2390  2019-08-13 19:22:13.6350
# 3  106972         83260  2019-08-15 11:09:51.2100  2019-08-16 10:17:31.6100
# 4  153915         81623  2019-08-08 16:11:43.3060  2019-08-09 14:52:07.1810
# 5   92415         80893  2019-08-18 09:41:17.9540  2019-08-19 08:09:31.6590
# 6  182113         80033  2019-08-04 20:19:31.6790  2019-08-05 18:33:25.6200
# 7  111093         79374  2019-08-14 20:50:01.3640  2019-08-15 18:52:55.4570
# 8  140017         79016  2019-08-11 10:50:48.1860  2019-08-12 08:47:44.8850
# 9   32813         78838  2019-08-26 12:13:18.5330  2019-08-27 10:07:17.5180
#
#    start_station_id            start_station_name  start_station_latitude  \
# 0               377         Fell St at Stanyan St               37.771951
# 1               387      Randall St at Chenery St               37.739813
# 2               356   Valencia St at Clinton Park               37.769188
# 3                78           Folsom St at 9th St               37.773717
# 4               269  Telegraph Ave at Carleton St               37.862320
# 5               197   El Embarcadero at Grand Ave               37.808848
# 6               129        Harrison St at 20th St               37.758862
# 7               182      19th Street BART Station               37.809013
# 8               133        Valencia St at 22nd St               37.755213
# 9               285    Webster St at O'Farrell St               37.783521
#
#    start_station_longitude  end_station_id  \
# 0              -122.453705             344
# 1              -122.425523              14
# 2              -122.422285             344
# 3              -122.411647             115
# 4              -122.258801             344
# 5              -122.249680             196
# 6              -122.412544              27
# 7              -122.268247             195
# 8              -122.420975              59
# 9              -122.431158              43
#
#                                     end_station_name  end_station_latitude  \
# 0                                      16th St Depot             37.766349
# 1                              Clay St at Battery St             37.795001
# 2                                      16th St Depot             37.766349
# 3                                 Jackson Playground             37.765026
# 4                                      16th St Depot             37.766349
# 5                            Grand Ave at Perkins St             37.808894
# 6                            Beale St at Harrison St             37.788059
# 7                                Bay Pl at Vernon St             37.812314
# 8                        S Van Ness Ave at Market St             37.774814
# 9  San Francisco Public Library (Grove St at Hyde...             37.778768
#
#    end_station_longitude  bike_id   user_type member_birth_year member_gender  \
# 0            -122.396292     9465    Customer
# 1            -122.399970    10150    Customer
# 2            -122.396292      262    Customer
# 3            -122.398773     3470    Customer
# 4            -122.396292     3527    Customer
# 5            -122.256460     1633    Customer              1965          Male
# 6            -122.391865     3028  Subscriber
# 7            -122.260779     3574  Subscriber              1988        Female
# 8            -122.418954      151  Subscriber              1988        Female
# 9            -122.415929    10315    Customer
#
#   bike_share_for_all_trip
# 0                      No
# 1                      No
# 2                      No
# 3                      No
# 4                      No
# 5                      No
# 6                      No
# 7                      No
# 8                      No
# 9                      No

# %%
streetmap = gdp.read_file('shape/sanfran_city/geo_export_b896081a-685e-4878-a962-38b650695c1a.shp')

# %%
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax)

# %%
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(birth_geo_df["start_station_longitude"], birth_geo_df["start_station_latitude"])]
geometry_end = [Point(xy) for xy in zip(birth_geo_df["end_station_longitude"], birth_geo_df["end_station_latitude"])]
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x1b8161b3388>,
#  <shapely.geometry.point.Point at 0x1b8161b3c88>,
#  <shapely.geometry.point.Point at 0x1b8161b3d08>]

# %%
geometry_end[:3]
# Out:
# [<shapely.geometry.point.Point at 0x1b8161b3cc8>,
#  <shapely.geometry.point.Point at 0x1b8161b3ec8>,
#  <shapely.geometry.point.Point at 0x1b879079608>]

# %%
birth_geo_df = gdp.GeoDataFrame(birth_geo_df,#Specify our data
                         crs = crs,#specify our coordinate reference system
                         geometry = geometry)#Specify the geometry list we created
birth_geo_df
# Out:
#        id  duration_sec                start_time                  end_time  \
# 0  137529         85492  2019-08-11 16:19:56.2900  2019-08-12 16:04:48.8640
# 1   17400         85314  2019-08-28 09:11:09.3100  2019-08-29 08:53:03.7980
# 2  127106         85252  2019-08-12 19:41:21.2390  2019-08-13 19:22:13.6350
# 3  106972         83260  2019-08-15 11:09:51.2100  2019-08-16 10:17:31.6100
# 4  153915         81623  2019-08-08 16:11:43.3060  2019-08-09 14:52:07.1810
# 5   92415         80893  2019-08-18 09:41:17.9540  2019-08-19 08:09:31.6590
# 6  182113         80033  2019-08-04 20:19:31.6790  2019-08-05 18:33:25.6200
# 7  111093         79374  2019-08-14 20:50:01.3640  2019-08-15 18:52:55.4570
# 8  140017         79016  2019-08-11 10:50:48.1860  2019-08-12 08:47:44.8850
# 9   32813         78838  2019-08-26 12:13:18.5330  2019-08-27 10:07:17.5180
#
#    start_station_id            start_station_name  start_station_latitude  \
# 0               377         Fell St at Stanyan St               37.771951
# 1               387      Randall St at Chenery St               37.739813
# 2               356   Valencia St at Clinton Park               37.769188
# 3                78           Folsom St at 9th St               37.773717
# 4               269  Telegraph Ave at Carleton St               37.862320
# 5               197   El Embarcadero at Grand Ave               37.808848
# 6               129        Harrison St at 20th St               37.758862
# 7               182      19th Street BART Station               37.809013
# 8               133        Valencia St at 22nd St               37.755213
# 9               285    Webster St at O'Farrell St               37.783521
#
#    start_station_longitude  end_station_id  \
# 0              -122.453705             344
# 1              -122.425523              14
# 2              -122.422285             344
# 3              -122.411647             115
# 4              -122.258801             344
# 5              -122.249680             196
# 6              -122.412544              27
# 7              -122.268247             195
# 8              -122.420975              59
# 9              -122.431158              43
#
#                                     end_station_name  end_station_latitude  \
# 0                                      16th St Depot             37.766349
# 1                              Clay St at Battery St             37.795001
# 2                                      16th St Depot             37.766349
# 3                                 Jackson Playground             37.765026
# 4                                      16th St Depot             37.766349
# 5                            Grand Ave at Perkins St             37.808894
# 6                            Beale St at Harrison St             37.788059
# 7                                Bay Pl at Vernon St             37.812314
# 8                        S Van Ness Ave at Market St             37.774814
# 9  San Francisco Public Library (Grove St at Hyde...             37.778768
#
#    end_station_longitude  bike_id   user_type member_birth_year member_gender  \
# 0            -122.396292     9465    Customer
# 1            -122.399970    10150    Customer
# 2            -122.396292      262    Customer
# 3            -122.398773     3470    Customer
# 4            -122.396292     3527    Customer
# 5            -122.256460     1633    Customer              1965          Male
# 6            -122.391865     3028  Subscriber
# 7            -122.260779     3574  Subscriber              1988        Female
# 8            -122.418954      151  Subscriber              1988        Female
# 9            -122.415929    10315    Customer
#
#   bike_share_for_all_trip                                      geometry
# 0                      No               POINT (-122.4537048 37.7719511)
# 1                      No   POINT (-122.425522506237 37.73981271734901)
# 2                      No   POINT (-122.422285079956 37.76918817810459)
# 3                      No               POINT (-122.4116467 37.7737172)
# 4                      No                POINT (-122.258801 37.8623199)
# 5                      No               POINT (-122.2496799 37.8088479)
# 6                      No                 POINT (-122.412544 37.758862)
# 7                      No               POINT (-122.2682473 37.8090126)
# 8                      No               POINT (-122.4209752 37.7552126)
# 9                      No  POINT (-122.4311578273773 37.78352083526095)

# %%
test = gdp.GeoDataFrame(birth_geo_df,#Specify our data
                         crs = crs,#specify our coordinate reference system
                         geometry = geometry_end)#Specify the geometry list we created
test
# Out:
#        id  duration_sec                start_time                  end_time  \
# 0  137529         85492  2019-08-11 16:19:56.2900  2019-08-12 16:04:48.8640
# 1   17400         85314  2019-08-28 09:11:09.3100  2019-08-29 08:53:03.7980
# 2  127106         85252  2019-08-12 19:41:21.2390  2019-08-13 19:22:13.6350
# 3  106972         83260  2019-08-15 11:09:51.2100  2019-08-16 10:17:31.6100
# 4  153915         81623  2019-08-08 16:11:43.3060  2019-08-09 14:52:07.1810
# 5   92415         80893  2019-08-18 09:41:17.9540  2019-08-19 08:09:31.6590
# 6  182113         80033  2019-08-04 20:19:31.6790  2019-08-05 18:33:25.6200
# 7  111093         79374  2019-08-14 20:50:01.3640  2019-08-15 18:52:55.4570
# 8  140017         79016  2019-08-11 10:50:48.1860  2019-08-12 08:47:44.8850
# 9   32813         78838  2019-08-26 12:13:18.5330  2019-08-27 10:07:17.5180
#
#    start_station_id            start_station_name  start_station_latitude  \
# 0               377         Fell St at Stanyan St               37.771951
# 1               387      Randall St at Chenery St               37.739813
# 2               356   Valencia St at Clinton Park               37.769188
# 3                78           Folsom St at 9th St               37.773717
# 4               269  Telegraph Ave at Carleton St               37.862320
# 5               197   El Embarcadero at Grand Ave               37.808848
# 6               129        Harrison St at 20th St               37.758862
# 7               182      19th Street BART Station               37.809013
# 8               133        Valencia St at 22nd St               37.755213
# 9               285    Webster St at O'Farrell St               37.783521
#
#    start_station_longitude  end_station_id  \
# 0              -122.453705             344
# 1              -122.425523              14
# 2              -122.422285             344
# 3              -122.411647             115
# 4              -122.258801             344
# 5              -122.249680             196
# 6              -122.412544              27
# 7              -122.268247             195
# 8              -122.420975              59
# 9              -122.431158              43
#
#                                     end_station_name  end_station_latitude  \
# 0                                      16th St Depot             37.766349
# 1                              Clay St at Battery St             37.795001
# 2                                      16th St Depot             37.766349
# 3                                 Jackson Playground             37.765026
# 4                                      16th St Depot             37.766349
# 5                            Grand Ave at Perkins St             37.808894
# 6                            Beale St at Harrison St             37.788059
# 7                                Bay Pl at Vernon St             37.812314
# 8                        S Van Ness Ave at Market St             37.774814
# 9  San Francisco Public Library (Grove St at Hyde...             37.778768
#
#    end_station_longitude  bike_id   user_type member_birth_year member_gender  \
# 0            -122.396292     9465    Customer
# 1            -122.399970    10150    Customer
# 2            -122.396292      262    Customer
# 3            -122.398773     3470    Customer
# 4            -122.396292     3527    Customer
# 5            -122.256460     1633    Customer              1965          Male
# 6            -122.391865     3028  Subscriber
# 7            -122.260779     3574  Subscriber              1988        Female
# 8            -122.418954      151  Subscriber              1988        Female
# 9            -122.415929    10315    Customer
#
#   bike_share_for_all_trip                                      geometry
# 0                      No  POINT (-122.3962917923927 37.76634858593739)
# 1                      No                  POINT (-122.39997 37.795001)
# 2                      No  POINT (-122.3962917923927 37.76634858593739)
# 3                      No               POINT (-122.3987734 37.7650259)
# 4                      No  POINT (-122.3962917923927 37.76634858593739)
# 5                      No  POINT (-122.2564601898193 37.80889393398715)
# 6                      No               POINT (-122.3918648 37.7880593)
# 7                      No  POINT (-122.2607785463333 37.81231409135146)
# 8                      No                 POINT (-122.418954 37.774814)
# 9                      No               POINT (-122.4159292 37.7787677)

# %%
fig,ax = plt.subplots(figsize = (15,15))
streetmap.plot(ax = ax, alpha = 0.4)

#birth_geo_df.plot(ax = ax, markersize = 20, color = "green", marker = "o", label = "Start Station Mil",alpha=0.99)
test.plot(ax = ax, markersize = 20, color = "blue", marker = "^", label = "Start Station Mil",alpha=0.99)
#boomers.plot(ax = ax, markersize = 20, color = "red", marker = "^", label = "Start Station boomers")
#ax.margins(x=0.25, y=-.10)   # Values in (-0.5, 0.0) zooms in to center
plt.legend(prop={'size': 15})
